# %%
from collections import defaultdict
import re

# %%
def word_occurence(para):
    freq = defaultdict(int)
    words = para.split(" ")
    for word in words:
        word = re.sub('[^A-Za-z]+', '', word)
        freq[word] += 1
    return dict(freq)

# %%
# testing
para = open('para.word', 'r', encoding='utf8').read()
word_occurence(para)
# Out:
# {'Machine': 2,
#  'learning': 19,
#  'is': 9,
#  'an': 2,
#  'application': 1,
#  'of': 10,
#  'artificial': 1,
#  'intelligence': 1,
#  'AI': 2,
#  'that': 5,
#  'provides': 1,
#  'systems': 3,
#  'the': 19,
#  'ability': 1,
#  'to': 18,
#  'automatically': 3,
#  'learn': 5,
#  'and': 16,
#  'improve': 2,
#  'from': 6,
#  'experience': 2,
#  'without': 2,
#  'being': 1,
#  'explicitly': 1,
#  'programmed': 1,
#  'focuses': 1,
#  'on': 2,
#  'development': 1,
#  'computer': 1,
#  'programs': 1,
#  'can': 6,
#  'access': 1,
#  'data': 12,
#  'use': 3,
#  'it': 8,
#  'for': 5,
#  'themselvesThe': 1,
#  'process': 1,
#  'begins': 1,
#  'with': 4,
#  'observations': 1,
#  'or': 6,
#  'such': 1,
#  'as': 3,
#  'examples': 3,
#  'direct': 1,
#  'instruction': 1,
#  'in': 10,
#  'order': 5,
#  'look': 1,
#  'patterns': 1,
#  'make': 3,
#  'better': 1,
#  'decisions': 1,
#  'future': 2,
#  'based': 1,
#  'we': 1,
#  'provide': 2,
#  'The': 5,
#  'primary': 1,
#  'aim': 1,
#  'allow': 1,
#  'computers': 1,
#  'human': 1,
#  'intervention': 1,
#  'assistance': 1,
#  'adjust': 1,
#  'actions': 2,
#  'accordinglySome': 1,
#  'machine': 6,
#  'methodsMachine': 1,
#  'algorithms': 5,
#  'are': 4,
#  'often': 1,
#  'categorized': 1,
#  'supervised': 2,
#  'unsupervisedSupervised': 1,
#  'apply': 1,
#  'what': 1,
#  'has': 1,
#  'been': 1,
#  'learned': 1,
#  'past': 1,
#  'new': 2,
#  'using': 1,
#  'labeled': 5,
#  'predict': 1,
#  'events': 1,
#  'Starting': 1,
#  'analysis': 2,
#  'a': 7,
#  'known': 2,
#  'training': 3,
#  'dataset': 1,
#  'algorithm': 2,
#  'produces': 1,
#  'inferred': 1,
#  'function': 2,
#  'predictions': 1,
#  'about': 1,
#  'output': 4,
#  'values': 1,
#  'system': 2,
#  'able': 2,
#  'targets': 1,
#  'any': 1,
#  'input': 1,
#  'after': 1,
#  'sufficient': 1,
#  'also': 2,
#  'compare': 1,
#  'its': 3,
#  'correct': 1,
#  'intended': 1,
#  'find': 1,
#  'errors': 2,
#  'modify': 1,
#  'model': 1,
#  'accordinglyIn': 1,
#  'contrast': 1,
#  'unsupervised': 2,
#  'used': 2,
#  'when': 2,
#  'information': 2,
#  'train': 3,
#  'neither': 1,
#  'classified': 1,
#  'nor': 1,
#  'Unsupervised': 1,
#  'studies': 1,
#  'how': 1,
#  'infer': 1,
#  'describe': 2,
#  'hidden': 2,
#  'structure': 1,
#  'unlabeled': 4,
#  'doesnt': 2,
#  'figure': 1,
#  'out': 1,
#  'right': 1,
#  'but': 1,
#  'explores': 1,
#  'draw': 1,
#  'inferences': 1,
#  'datasets': 1,
#  'structures': 1,
#  'dataSemisupervised': 1,
#  'fall': 1,
#  'somewhere': 1,
#  'between': 1,
#  'since': 1,
#  'they': 1,
#  'both': 1,
#  '': 2,
#  'typically': 1,
#  'small': 1,
#  'amount': 2,
#  'large': 2,
#  'this': 2,
#  'method': 3,
#  'considerably': 1,
#  'accuracy': 1,
#  'Usually': 1,
#  'semisupervised': 1,
#  'chosen': 1,
#  'acquired': 1,
#  'requires': 1,
#  'skilled': 1,
#  'relevant': 2,
#  'resources': 2,
#  'Otherwise': 1,
#  'acquiringunlabeled': 1,
#  'generally': 2,
#  'require': 2,
#  'additional': 2,
#  'resourcesReinforcement': 1,
#  'interacts': 1,
#  'environment': 1,
#  'by': 1,
#  'producing': 1,
#  'discovers': 1,
#  'rewards': 1,
#  'Trial': 1,
#  'error': 1,
#  'search': 1,
#  'delayed': 1,
#  'reward': 2,
#  'most': 1,
#  'characteristics': 1,
#  'reinforcement': 2,
#  'This': 1,
#  'allows': 1,
#  'machines': 1,
#  'software': 1,
#  'agents': 1,
#  'determine': 1,
#  'ideal': 1,
#  'behavior': 1,
#  'within': 1,
#  'specific': 1,
#  'context': 1,
#  'maximize': 1,
#  'performance': 1,
#  'Simple': 1,
#  'feedback': 1,
#  'required': 1,
#  'agent': 1,
#  'which': 1,
#  'action': 1,
#  'best': 1,
#  'signalMachine': 1,
#  'enables': 1,
#  'massive': 1,
#  'quantities': 1,
#  'While': 1,
#  'delivers': 1,
#  'faster': 1,
#  'more': 2,
#  'accurate': 1,
#  'results': 1,
#  'identify': 1,
#  'profitable': 1,
#  'opportunities': 1,
#  'dangerous': 1,
#  'risks': 1,
#  'may': 1,
#  'time': 1,
#  'properly': 1,
#  'Combining': 1,
#  'cognitive': 1,
#  'technologies': 1,
#  'even': 1,
#  'effective': 1,
#  'processing': 1,
#  'volumes': 1}

# %%
# test cases
import unittest
import os
import sys 
class Test_word_occurence(unittest.TestCase):
    def test_file_exists(self):
        self.assertTrue(os.path.isfile('para.word'))
    
    def test_file_content_exists(self):
        self.assertTrue(os.stat('para.word').st_size != 0)
    
    def test_file_content_type(self):
        self.assertEqual(type(para), str)
        
    # to assert that the returned value is a dict 
    def test_return_value_type(self):
        self.assertEqual(type(word_occurence(para)), dict)
        
    def test_return_value_size(self):
        self.assertTrue(len(word_occurence(para)) != 0)
    
    
    
if __name__ == '__main__':
    unittest.main(argv='v', exit = False)
# Out:
# .....
# ----------------------------------------------------------------------
# Ran 5 tests in 0.009s
#
# OK
